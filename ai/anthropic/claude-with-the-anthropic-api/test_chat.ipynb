# %%
# Imports

from dotenv import load_dotenv
from anthropic import Anthropic

# %%
# Client Initialization and helper functions

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"


def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(messages, text="When use java instead of python?")

chat(messages)
# Out:
# '# When to Use Java Instead of Python\n\n## **Performance & Speed**\n- **Java wins** for computationally intensive tasks\n- JIT compilation makes Java 5-10x faster than Python\n- Better for real-time systems, high-frequency trading, scientific computing\n\n```java\n// Java: Fast number crunching\nfor(int i = 0; i < 1_000_000_000; i++) {\n    // Much faster than Python\n}\n```\n\n## **Large-Scale Applications**\n- **Java** for enterprise systems with millions of lines of code\n- Better code organization with strong typing\n- Easier refactoring in large teams\n\n## **Concurrency & Multithreading**\n```java\n// Java: True multithreading\nThread t1 = new Thread(() -> doWork());\nThread t2 = new Thread(() -> doWork());\nt1.start();\nt2.start();\n```\nPython has GIL (Global Interpreter Lock) limitations\n\n## **Type Safety**\n```java\n// Java: Compile-time type checking\nint age = "25"; // ❌ Compile error caught early\n```\nPython errors appear at runtime\n\n## **Memory Management**\n- Java\'s garbage collector is more sophisticated\n- Better for long-running applications\n- Python can leak memory with circular references\n\n## **When Java is Better**\n\n| Use Case | Why |\n|----------|-----|\n| **Microservices** | Spring Boot ecosystem, containerization |\n| **Android Apps** | Native language for Android |\n| **Banking/Finance** | Stability, security, performance |\n| **Real-time Systems** | Predictable performance |\n| **High Traffic APIs** | Can handle more concurrent requests |\n\n## **When Python is Better**\n- Quick prototyping & MVP\n- Data science & ML\n- Scripting & automation\n- Learning to code\n- When speed of development > speed of execution\n\n**Bottom line:** Use Java for *production systems at scale*, Python for *rapid development and data work*.'
